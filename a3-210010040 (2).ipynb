# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

# %% [markdown]
# #### Question 1

# %%
xs = np.linspace(0.0,2*np.pi, 100000)
ys = 1-4*(np.sin(2*np.pi*xs))**2

plt.plot(xs,ys)
plt.title('Cp variation as that of theta')
# Out:
# Text(0.5, 1.0, 'Cp variation as that of theta')

# %%
U=2
v=-2*U*np.sin(xs)

plt.plot(xs,v)
plt.title('surface velocity distribution')
# Out:
# Text(0.5, 1.0, 'surface velocity distribution')

# %% [markdown]
# ### Question 6

# %%
radius=1


gamma = 5
cp_ro_cy= 1-4*(np.sin(2*np.pi*xs))**2 - (2*gamma*np.sin(xs))/(np.pi*U) - ((gamma**2)/(4*np.pi*np.pi*U*U))
plt.plot(xs,cp_ro_cy)

gamma = 6
cp_ro_cy= 1-4*(np.sin(2*np.pi*xs))**2 - (2*gamma*np.sin(xs))/(np.pi*U) - ((gamma**2)/(4*np.pi*np.pi*U*U))
plt.plot(xs,cp_ro_cy)

gamma = 7
cp_ro_cy= 1-4*(np.sin(2*np.pi*xs))**2 - (2*gamma*np.sin(xs))/(np.pi*U) - ((gamma**2)/(4*np.pi*np.pi*U*U))
plt.plot(xs,cp_ro_cy)

gamma = 8
cp_ro_cy= 1-4*(np.sin(2*np.pi*xs))**2 - (2*gamma*np.sin(xs))/(np.pi*U) - ((gamma**2)/(4*np.pi*np.pi*U*U))
plt.plot(xs,cp_ro_cy)






plt.title('Cp distrubution for rotating cylinder')
# Out:
# Text(0.5, 1.0, 'Cp distrubution for rotating cylinder')

# %% [markdown]
# ### Question 5

# %%
v_ro_cy= -2*U*np.sin(xs)- gamma/2*np.pi*1

plt.plot(xs,v_ro_cy)
plt.title('surface velocity distribution for rotating cylinder')
# Out:
# Text(0.5, 1.0, 'surface velocity distribution for rotating cylinder')

# %% [markdown]
# ### Question 7

# %% [markdown]
# cd= − int(Cp cosx dx)/2
# cl= - int(Cl sinx dx)/2
# fx=0
# fy=  $\rh$*U*gamma
